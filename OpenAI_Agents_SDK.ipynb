# %% [markdown]
# <p align = "center" draggable=”false” ><img src="https://github.com/AI-Maker-Space/LLM-Dev-101/assets/37101144/d1343317-fa2f-41e1-8af1-1dbb18399719"
#      width="200px"
#      height="auto"/>
# </p>
#
# <h1 align="center" id="heading">OpenAI Agents SDK - AIM</h1>
#
# In this notebook, we'll go over some of the key features of the OpenAI Agents SDK - as explored through a notebook-ified version of their [Research Bot](https://github.com/openai/openai-agents-python/tree/main/examples/research_bot).

# %%
### You don't need to run this cell if you're running this notebook locally. 

#!pip install -qU openai-agents

# %% [markdown]
# API Key:

# %%
import os 
import getpass

os.environ["OPENAI_API_KEY"] = getpass.getpass()

# %% [markdown]
# Nest Async:

# %%
import nest_asyncio
nest_asyncio.apply()

# %% [markdown]
# ## Agents
#
# As may be expected, the primary thing we'll do in the Agents SDK is construct Agents!
#
# Agents are constructed with a few basic properties:
#
# - A prompt, which OpenAI is using the language "instruction" for, that determines the behaviour or goal of the Agent
# - A model, the "brain" of the Agent
#
# They also typically include an additional property:
#
# - Tool(s) that equip the Agent with things it can use to get stuff done

# %% [markdown]
# ### Task 1: Create Planner Agent
#
# Let's start by creating our "Planner Agent" - which will come up with the initial set of search terms that should answer a query provided by the user.

# %%
from pydantic import BaseModel
from agents import Agent

PLANNER_PROMPT = (
    "You are a helpful research assistant. Given a query, come up with a set of web searches to perform" 
    "to best answer the query. Output between 5 and 20 terms to query for."
)

# %% [markdown]
# Next, we'll define the data models that our Planner Agent will use to structure its output. We'll create:
#
# 1. `WebSearchItem` - A model for individual search items, containing the search query and reasoning
# 2. `WebSearchPlan` - A container model that holds a list of search items
#
# These Pydantic models will help ensure our agent returns structured data that we can easily process.

# %%
class WebSearchItem(BaseModel):
    reason: str
    "Your reasoning for why this search is important to the query."

    query: str
    "The search term to use for the web search."

class WebSearchPlan(BaseModel):
    searches: list[WebSearchItem]
    """A list of web searches to perform to best answer the query."""

# %% [markdown]
# Now we'll create our Planner Agent using the Agent class from the OpenAI Agents SDK. This agent will use the instructions defined in `PLANNER_PROMPT` and will output structured data in the form of our WebSearchPlan model. We're using the GPT-4o model for this agent to ensure high-quality search term generation.
#
# > NOTE: When we provide an `output_type` - the model will return a [structured response](https://platform.openai.com/docs/guides/structured-outputs?api-mode=responses).

# %%
planner_agent = Agent(
    name="PlannerAgent",
    instructions=PLANNER_PROMPT,
    model="gpt-4.1",
    output_type=WebSearchPlan,
)

# %% [markdown]
# #### ❓Question #1:
#
# Why is it important to provide a structured response template? (As in: Why are structured outputs helpful/preferred in Agentic workflows?)

# %% [markdown]
# #### ✅ Answer :
#
# Structured outputs are crucial in Agentic workflows for several key reasons:
#
# 🔶 1. Consistency and Reliability
#
# 🔹Structured responses ensure agents return data in a predictable, consistent format
#
# 🔹 This prevents parsing errors and makes downstream processing more reliable
#
# 🔹 Each agent knows exactly what format to expect from other agents
#
# 🔶 2. Type Safety and Validation
#
# 🔹 Using Pydantic models (like WebSearchPlan) provides automatic validation
#
# 🔹 Catches errors early in the workflow before they propagate
#
# 🔹 Ensures data integrity throughout the multi-agent system
#
# 🔶 3. Seamless Agent Handoffs
#
# 🔹 In multi-agent workflows (like Planner → Search → Writer), structured outputs enable smooth transitions
#
# 🔹 No manual parsing or data transformation needed between agents
#
# 🔹 Each agent can directly use the structured output from previous agents
#
# 🔶 4. Enhanced Debugging and Observability
#
# 🔹 Structured outputs make it easier to trace what each agent produced
#
# 🔹 Better monitoring and debugging capabilities
#
# 🔹 Clear visibility into the data flow between agents
#
# 🔶 5. Tool Integration
#
# 🔹 Many external tools and APIs expect specific data formats
#
# 🔹 Structured outputs ensure compatibility with various tools and services
#
# 🔹 Enables reliable integration with databases, APIs, and other systems
#
# 🔶 6. Scalability
#
# 🔹 As workflows become more complex, structured outputs maintain order
#
# 🔹 Easier to add new agents or modify existing ones
#
# 🔹 Reduces the risk of breaking changes when extending the system
#
# In our research bot example, the WebSearchPlan structure ensures that the Planner Agent's output can be directly consumed by the Search Agent, creating a reliable and maintainable workflow.

# %% [markdown]
# ### Task 2: Create Search Agent
#
# Now we'll create our Search Agent, which will be responsible for executing web searches based on the terms generated by the Planner Agent. This agent will take each search query, perform a web search using the `WebSearchTool`, and then summarize the results in a concise format.
#
# > NOTE: We are using the `WebSearchTool`, a hosted tool that can be used as part of an `OpenAIResponsesModel` as outlined in the [documentation](https://openai.github.io/openai-agents-python/tools/). This is based on the tools available through OpenAI's new [Responses API](https://openai.com/index/new-tools-for-building-agents/).
#
# The `SEARCH_PROMPT` below instructs the agent to create brief, focused summaries of search results. These summaries are designed to be 2-3 paragraphs, under 300 words, and capture only the essential information without unnecessary details. The goal is to provide the Writer Agent with clear, distilled information that can be efficiently synthesized into the final report.

# %%
SEARCH_PROMPT = (
    "You are a research assistant. Given a search term, you search the web for that term and"
    "produce a concise summary of the results. The summary must 2-3 paragraphs and less than 300"
    "words. Capture the main points. Write succinctly, no need to have complete sentences or good"
    "grammar. This will be consumed by someone synthesizing a report, so its vital you capture the"
    "essence and ignore any fluff. Do not include any additional commentary other than the summary"
    "itself."
)

# %% [markdown]
# Now we'll create our Search Agent using the Agent class from the OpenAI Agents SDK. This agent will use the instructions defined in `SEARCH_PROMPT` and will utilize the `WebSearchTool` to perform web searches. We're configuring it with `tool_choice="required"` to ensure it always uses the search tool when processing requests.
#
# > NOTE: We can, as demonstrated, indicate how we want our model to use tools. You can read more about that at the bottom of the page [here](https://openai.github.io/openai-agents-python/agents/)

# %%
from agents import WebSearchTool
from agents.model_settings import ModelSettings

search_agent = Agent(
    name="Search agent",
    instructions=SEARCH_PROMPT,
    tools=[WebSearchTool()],
    model_settings=ModelSettings(tool_choice="required"),
)

# %% [markdown]
# #### ❓ Question #2:
#
# What other tools are supported in OpenAI's Responses API?

# %% [markdown]
# #### ✅ Answer :
#
# In addition to the `WebSearchTool` used (explained again in detail below) for Search Agent, OpenAI's Responses API supports several other built-in tools that agents can utilize:
#
# 🔷 Web Search Tool (web_search_preview)
#
# ▫️Performs web searches for latest information
#
# ▫️Available with gpt-4o, gpt-4o-mini, and other models
#
# ▫️Provides inline citations with URLs and titles
#
# ▫️Supports user location customization for geography-based results
#
# ▫️Configurable search context size (low/medium/high)
#
# ▫️Multiple search actions (search, open_page, find_in_page)
#
# ▫️Tool choice configuration for consistent results
#
# 🔷 File Search Tool (file_search)
#
# ▫️Searches through uploaded files in vector stores
#
# ▫️Supports semantic and keyword search across knowledge bases
#
# ▫️Includes file citations with file_id and filename
#
# ▫️Supports metadata filtering and result limiting
#
# ▫️Compatible with multiple file formats (PDF, DOCX, TXT, MD, etc.)
#
# ▫️Rate limits: 100-1000 RPM depending on tier
#
# ▫️Integration with vector stores for knowledge bases
#
# 🔷 Image Generation Tool (image_generation)
#
# ▫️Generates images using text prompts
#
# ▫️Leverages the GPT Image model (gpt-image-1)
#
# ▫️Supports multiple output options (size, quality, format, compression, background)
#
# ▫️Includes automatic prompt revision for improved performance
#
# ▫️Supports multi-turn editing with previous response/image IDs
#
# ▫️Provides streaming partial images for faster feedback
#
# ▫️Available with models: gpt-4o, gpt-4o-mini, gpt-4.1, gpt-4.1-mini, gpt-4.1-nano, o3
#
# 🔷 Code Interpreter Tool (code_interpreter)
#
# ▫️Allows models to write and run Python code in a sandboxed environment
#
# ▫️Supports data analysis, coding, and mathematical problem-solving
#
# ▫️Can process files with diverse data and formatting
#
# ▫️Generates files with data and images of graphs
#
# ▫️Boosts visual intelligence in reasoning models (o3, o4-mini)
#
# ▫️Supports image processing (crop, zoom, rotate, transform)
#
# ▫️Rate limit: 100 RPM per organization
#
# ▫️Uses containers (auto or explicit mode) with 20-minute expiration
#
# ▫️Supports multiple file formats for input/output
#
# 🔷 Computer Use Tool (computer_use_preview)
#
# ▫️Enables agents to perform tasks on computers through automation
#
# ▫️Powered by the Computer-Using Agent (CUA) model
#
# ▫️Operates in a continuous loop: sends actions → executes → captures screenshots
#
# ▫️Supports actions like click, type, scroll, keypress, wait, screenshot
#
# ▫️Available for browser, mac, windows, and ubuntu environments
#
# ▫️Includes safety checks for malicious instructions, irrelevant domains, and sensitive domains
#
# ▫️Requires human oversight for high-stakes tasks
#
# ▫️Currently in beta with limitations (38.1% success on OSWorld)
#
# ▫️Supports conversation history management and safety check acknowledgment
#
# 🔷 Remote MCP Servers Tool (mcp)
#
# ▫️Connects to third-party Model Context Protocol servers
#
# ▫️Supports authentication via headers for secure connections
#
# ▫️Includes approval workflows for security and control
#
# ▫️Supports tool filtering with allowed_tools parameter
#
# ▫️Compatible with Streamable HTTP and HTTP/SSE transport protocols
#
# ▫️Integrates with services like Stripe, HubSpot, Intercom, PayPal, etc.
#
# ▫️Rate limits: 200-2000 RPM depending on tier
#
# Additional Hosted Tools
#
# 🔷 HostedMCPTool: Exposes a remote MCP server's tools to the model
#
# 🔷 LocalShellTool: Runs shell commands on your machine
#
# 🔷 Function Tools
#
# ▫️Custom Python Functions: Any Python function can be used as a tool
#
# ▫️Automatic Schema Generation: Function signatures and docstrings are automatically parsed
#
# ▫️Error Handling: Built-in error handling with customizable failure responses
#
# ▫️Type Support: Supports Python primitives, Pydantic models, TypedDicts, and more
#
# 🔷 Agents as Tools
#
# ▫️Agent Orchestration: Agents can call other agents as tools without handoffs
#
# ▫️Custom Output Extraction: Modify agent outputs before returning to central agent
#
# ▫️Advanced Configuration: Custom run configurations and parameters
#
# Key Features Across All Tools
#
# ▫️Unified item-based design
#
# ▫️Simpler polymorphism
#
# ▫️Intuitive streaming events
#
# ▫️SDK helpers like response.output_text
#
# ▫️Built-in tracing and observability
#
# ▫️Tool choice configuration for consistent results
#
# ▫️Support for Zero Data Retention and Data Residency
#
# These tools provide agents with diverse capabilities for web search, file operations, image generation, code execution, computer automation, function calling, agent orchestration, shell command execution, and custom integrations, making them highly versatile for various applications.

# %% [markdown]
# ### Task 3: Create Writer Agent
#
# Finally, we'll create our Writer Agent, which will synthesize all the research findings into a comprehensive report. This agent takes the original query and the research summaries from the Search Agent, then produces a structured report with follow-up questions.
#
# The Writer Agent will:
# 1. Create an outline for the report structure
# 2. Generate a detailed markdown report (5-10 pages)
# 3. Provide follow-up questions for further research
#
# We'll define the prompt for this agent in the next cell. This prompt will instruct the Writer Agent on how to synthesize research findings into a comprehensive report with follow-up questions.

# %%
WRITER_PROMPT = (
    "You are a senior researcher tasked with writing a cohesive report for a research query. "
    "You will be provided with the original query, and some initial research done by a research "
    "assistant.\n"
    "You should first come up with an outline for the report that describes the structure and "
    "flow of the report. Then, generate the report and return that as your final output.\n"
    "The final output should be in markdown format, and it should be lengthy and detailed. Aim "
    "for 5-10 pages of content, at least 1000 words.\n"
    "For the follow-up questions, provide exactly 5 unique questions that would help extend "
    "this research. Do not repeat questions."
)

# %% [markdown]
# #### 🏗️ Activity #1:
#
# This prompt is quite generic - modify this prompt to produce a report that is more personalized to either your personal preference, or more appropriate for a specific use case (eg. law domain research)

# %% [markdown]
# #### ✅ Answer :
#
# Here's the modified WRITER_PROMPT for medical domain research:
#
# This modified prompt transforms the generic research assistant into a specialized medical researcher, incorporating medical writing conventions, clinical terminology, and evidence-based research standards.

# %%
WRITER_PROMPT = (
    "You are a senior medical researcher and healthcare professional tasked with writing a comprehensive "
    "medical research report. You will be provided with the original query and initial research findings.\n"
    "You should first create a detailed medical report outline following standard medical writing "
    "conventions, including: Abstract, Introduction, Methods, Results, Discussion, and Conclusion.\n"
    "The final output should be in markdown format, written in clear medical terminology accessible "
    "to healthcare professionals. Aim for 5-10 pages of content, at least 1200 words.\n"
    "Include relevant clinical studies, medical guidelines, and evidence-based practices where applicable. "
    "Maintain scientific rigor and cite medical literature appropriately.\n"
    "For follow-up questions, provide exactly 5 unique questions that would help extend this medical "
    "research, focusing on clinical trials, treatment protocols, or patient outcomes."
)

# %% [markdown]
# Now we'll create our Writer Agent using the Agent class from the OpenAI Agents SDK. This agent will synthesize all the research findings into a comprehensive report. We're configuring it with the `ReportData` output type to structure the response with a short summary, markdown report, and follow-up questions.

# %%
class ReportData(BaseModel):
    short_summary: str
    """A short 2-3 sentence summary of the findings."""

    markdown_report: str
    """The final report"""

    follow_up_questions: list[str]
    """Suggested topics to research further"""

# %% [markdown]
# Now we'll define our Writer Agent using the Agent class from the OpenAI Agents SDK. This agent will take the original query and research summaries, then synthesize them into a comprehensive report with follow-up questions. We've defined a custom output type called `ReportData` that structures the response with a short summary, markdown report, and follow-up questions.

# %%
writer_agent = Agent(
    name="WriterAgent",
    instructions=WRITER_PROMPT,
    model="o3-mini",
    output_type=ReportData,
)

# %% [markdown]
# #### ❓ Question #3:
#
# Why are we electing to use a reasoning model for writing our report?

# %% [markdown]
# #### ✅ Answer :
#
# We are electing to use a reasoning model (o3-mini) for the Writer Agent because:
#
# 💠 Complex Synthesis Requirements
#
# 🔺 The Writer Agent must synthesize multiple research findings from the Search Agent into a cohesive, comprehensive report
#
# 🔺It needs to identify patterns, contradictions, and connections across diverse sources
#
# 🔺Reasoning models excel at this type of complex information synthesis
#
# 💠 Multi-step Cognitive Process
#
# 🔺The Writer Agent performs multiple reasoning steps: creating an outline, generating content, and formulating follow-up questions
#
# 🔺Reasoning models are specifically designed to handle multi-step cognitive tasks
#
# 🔺They can maintain context and logical flow across the entire report generation process
#
# 💠 Quality and Coherence
#
# 🔺Reasoning models produce higher-quality, more coherent reports with better logical structure
#
# 🔺They can better understand the context and nuances of the research query and findings
#
# 🔺This leads to more insightful and well-organized reports compared to simpler models
#
# 💠 Advanced Problem-Solving
#
# 🔺Writing a comprehensive report requires advanced problem-solving capabilities
#
# 🔺Reasoning models can handle the complexity of organizing information, identifying key insights, and presenting them logically
#
# 🔺They excel at tasks that require deep understanding and synthesis
#
# 💠 Structured Output Generation
#
# 🔺The Writer Agent must produce structured output (ReportData) with specific components
#
# 🔺Reasoning models are better at following complex instructions and generating structured, consistent outputs
#
# 🔺They can maintain the required format while ensuring content quality

# %% [markdown]
# ## Task 4: Create Utility Classes
#
# We'll define utility classes to help with displaying progress and managing the research workflow. The Printer class below will provide real-time updates on the research process.

# %% [markdown]
# The Printer class provides real-time progress updates during the research process. It uses Rich's Live display to show dynamic content with spinners for in-progress items and checkmarks for completed tasks. The class maintains a dictionary of items with their completion status and can selectively hide checkmarks for specific items. This creates a clean, interactive console experience that keeps the user informed about the current state of the research workflow.

# %%
from typing import Any

from rich.console import Console, Group
from rich.live import Live
from rich.spinner import Spinner

class Printer:
    def __init__(self, console: Console):
        self.live = Live(console=console)
        self.items: dict[str, tuple[str, bool]] = {}
        self.hide_done_ids: set[str] = set()
        self.live.start()

    def end(self) -> None:
        self.live.stop()

    def hide_done_checkmark(self, item_id: str) -> None:
        self.hide_done_ids.add(item_id)

    def update_item(
        self, item_id: str, content: str, is_done: bool = False, hide_checkmark: bool = False
    ) -> None:
        self.items[item_id] = (content, is_done)
        if hide_checkmark:
            self.hide_done_ids.add(item_id)
        self.flush()

    def mark_item_done(self, item_id: str) -> None:
        self.items[item_id] = (self.items[item_id][0], True)
        self.flush()

    def flush(self) -> None:
        renderables: list[Any] = []
        for item_id, (content, is_done) in self.items.items():
            if is_done:
                prefix = "✅ " if item_id not in self.hide_done_ids else ""
                renderables.append(prefix + content)
            else:
                renderables.append(Spinner("dots", text=content))
        self.live.update(Group(*renderables))

# %% [markdown]
# Let's create a ResearchManager class that will orchestrate the research process. This class will:
# 1. Plan searches based on the query
# 2. Perform those searches to gather information
# 3. Write a comprehensive report based on the gathered information
# 4. Display progress using our Printer class

# %%
from __future__ import annotations

import asyncio
import time

from agents import Runner, custom_span, gen_trace_id, trace

class ResearchManager:
    def __init__(self):
        self.console = Console()
        self.printer = Printer(self.console)

    async def run(self, query: str) -> None:
        trace_id = gen_trace_id()
        with trace("Research trace", trace_id=trace_id):
            self.printer.update_item(
                "trace_id",
                f"View trace: https://platform.openai.com/traces/trace?trace_id={trace_id}",
                is_done=True,
                hide_checkmark=True,
            )

            self.printer.update_item(
                "starting",
                "Starting research...",
                is_done=True,
                hide_checkmark=True,
            )
            search_plan = await self._plan_searches(query)
            search_results = await self._perform_searches(search_plan)
            report = await self._write_report(query, search_results)

            final_report = f"Report summary\n\n{report.short_summary}"
            self.printer.update_item("final_report", final_report, is_done=True)

            self.printer.end()

        print("\n\n=====REPORT=====\n\n")
        print(f"Report: {report.markdown_report}")
        print("\n\n=====FOLLOW UP QUESTIONS=====\n\n")
        unique_questions = []
        seen = set()
        
        for question in report.follow_up_questions:
            if question not in seen:
                unique_questions.append(question)
                seen.add(question)
        
        for i, question in enumerate(unique_questions, 1):
            print(f"{i}. {question}")

    async def _plan_searches(self, query: str) -> WebSearchPlan:
        self.printer.update_item("planning", "Planning searches...")
        result = await Runner.run(
            planner_agent,
            f"Query: {query}",
        )
        self.printer.update_item(
            "planning",
            f"Will perform {len(result.final_output.searches)} searches",
            is_done=True,
        )
        return result.final_output_as(WebSearchPlan)

    async def _perform_searches(self, search_plan: WebSearchPlan) -> list[str]:
        with custom_span("Search the web"):
            self.printer.update_item("searching", "Searching...")
            num_completed = 0
            max_concurrent = 5
            results = []
            
            for i in range(0, len(search_plan.searches), max_concurrent):
                batch = search_plan.searches[i:i+max_concurrent]
                tasks = [asyncio.create_task(self._search(item)) for item in batch]
                
                for task in asyncio.as_completed(tasks):
                    try:
                        result = await task
                        if result is not None:
                            results.append(result)
                    except Exception as e:
                        print(f"Search error: {e}")
                        
                    num_completed += 1
                    self.printer.update_item(
                        "searching", f"Searching... {num_completed}/{len(search_plan.searches)} completed"
                    )
            
            self.printer.mark_item_done("searching")
            return results

    async def _search(self, item: WebSearchItem) -> str | None:
        input = f"Search term: {item.query}\nReason for searching: {item.reason}"
        try:
            result = await Runner.run(
                search_agent,
                input,
            )
            return str(result.final_output)
        except Exception as e:
            print(f"Error searching for '{item.query}': {e}")
            return None

    async def _write_report(self, query: str, search_results: list[str]) -> ReportData:
        self.printer.update_item("writing", "Thinking about report...")
        input = f"Original query: {query}\nSummarized search results: {search_results}"
        
        result = Runner.run_streamed(
            writer_agent,
            input,
        )
        
        update_messages = [
            "Thinking about report...",
            "Planning report structure...",
            "Writing outline...",
            "Creating sections...",
            "Cleaning up formatting...",
            "Finalizing report...",
            "Finishing report...",
        ]

        last_update = time.time()
        next_message = 0
        
        async for event in result.stream_events():
            if time.time() - last_update > 5 and next_message < len(update_messages):
                self.printer.update_item("writing", update_messages[next_message])
                next_message += 1
                last_update = time.time()

        self.printer.mark_item_done("writing")
        return result.final_output_as(ReportData)

# %% [markdown]
# #### 🏗️ Activity #2:
#
# Convert the above flow into a flowchart style image (software of your choosing, but if you're not sure which to use try [Excallidraw](https://excalidraw.com/)) that outlines how the different Agents interact with each other.
#
# > HINT: Cursor's AI (CMD+L or CTRL+L on Windows) would be a helpful way to get a basic diagram that you can add more detail to!

# %% [markdown]
# #### ✅ Answer :
#
# The flowchart illustrates the ResearchManager's multi-agent research workflow, starting with a user query that flows through three specialized agents. The Planner Agent (gpt-4.1) generates structured search terms (WebSearchPlan), which are then processed by the Search Agent (gpt-4.1 + WebSearchTool) performing up to 5 concurrent web searches and summaries.
#
# Finally, the Writer Agent (o3-mini reasoning model) synthesizes all findings into a comprehensive ReportData output containing a summary, detailed report, and follow-up questions. The diagram shows bidirectional communication between agents, error handling mechanisms, and streaming progress updates throughout the process.

# %% [markdown]
# ![ResearchManager Agent Flowchart](FlowChart_AgentsSDK.png)

# %% [markdown]
# ## Task 5: Running Our Agent
#
# Now let's run our agent! The main function below will prompt the user for a research topic, then pass that query to our ResearchManager to handle the entire research process. The ResearchManager will:
#
# 1. Break down the query into search items
# 2. Search for information on each item
# 3. Write a comprehensive report based on the search results
#
# Let's see it in action!

# %%
async def main() -> None:
    query = input("What would you like to research? ")
    await ResearchManager().run(query)

# %%
asyncio.run(main())
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# =====REPORT=====
#
#
# Report: # Prevention of Diabetes in Females
#
# ## Abstract
#
# Type 2 diabetes (T2D) represents a significant public health challenge worldwide, with women facing unique risk factors that predispose them to the disease. This report provides an in-depth analysis of preventive strategies aimed at reducing diabetes risk among females. It reviews the impact of lifestyle modifications, hormonal changes, and ethnic disparities on the development of T2D, and evaluates relevant clinical guidelines and research evidence. By summarizing data from systematic reviews and clinical studies, this report outlines practical recommendations for healthcare professionals that are grounded in evidence-based practices. The overall goal is to disseminate comprehensive guidelines for preventing diabetes in women, thereby reducing future morbidity and healthcare expenditure.
#
# ## Introduction
#
# Diabetes prevalence has been steadily increasing, affecting millions of individuals globally. Women are particularly at risk due to factors such as gestational diabetes, polycystic ovary syndrome (PCOS), and menopause-related hormonal changes. The interplay of biological, socioeconomic, and behavioral factors necessitates tailored prevention strategies. Research consistently demonstrates that lifestyle interventions—specifically, dietary modification, regular physical activity, and weight management—can significantly decrease the incidence of T2D among women. This report aims to explore these preventive measures, detailing both physiological mechanisms and evidence-based guidelines to empower healthcare providers in reducing diabetes risk in female populations.
#
# ## Methods
#
# This report synthesizes a comprehensive review of the literature, including observational studies, systematic reviews, meta-analyses, and clinical guidelines, from sources such as the American Diabetes Association (ADA), the National Institute of Diabetes and Digestive and Kidney Diseases (NIDDK), and peer-reviewed journals. The research methodology included the following steps:
#
# 1. **Literature Search:** Multiple databases were queried for studies focusing on diabetes prevention in females. Keywords such as "female diabetes prevention", "physical activity diabetes", "gestational diabetes", and "lifestyle interventions in women" guided the search.
#
# 2. **Data Extraction:** Emphasis was placed on extracting data related to physical activity recommendations, weight management strategies, dietary interventions, and the influence of hormonal and ethnic factors on diabetes risk.
#
# 3. **Critical Appraisal:** Studies were evaluated for methodological quality, potential bias, and if their findings were consistent with current clinical guidelines. Studies funded by reputable institutions such as the ADA and Mayo Clinic were prioritized.
#
# 4. **Synthesis of Evidence:** Findings were organized into thematic sections addressing lifestyle modifications, risk factors, and specific populations at risk (e.g., women with a history of gestational diabetes, ethnic minorities, and those entering menopause).
#
# ## Results
#
# ### Lifestyle Modifications
#
# **Physical Activity:** Consistent evidence supports that regular physical activity is integral to diabetes prevention. The ADA recommends at least 150 minutes of moderate-intensity aerobic exercise per week (e.g., brisk walking, cycling, or swimming) along with resistance training on two to three non-consecutive days. These activities are known to improve insulin sensitivity and contribute to weight management. Studies have demonstrated that even modest levels of regular exercise can significantly reduce insulin resistance and metabolic risk factors among women.
#
# **Weight Management:** Numerous clinical studies indicate that losing 5% to 7% of body weight can yield substantial benefits in reducing diabetes risk. Maintaining a healthy weight, particularly by controlling abdominal adiposity, plays a crucial role in improving insulin sensitivity. Enhanced physical activity combined with dietary modifications focused on calorie restriction and nutrient density have been shown to lower the risk of progression from prediabetes to overt T2D.
#
# **Nutritional Interventions:** A diet rich in fiber—emphasizing whole grains, fruits, vegetables, and legumes—has been linked to stabilizing blood glucose levels and promoting satiety. In contrast, diets high in refined carbohydrates, sugars, and unhealthy fats elevate the risk of T2D. Additionally, emerging research supports the adoption of plant-based dietary patterns, which also assist in maintaining overall metabolic health. Public health guidelines recommend reducing saturated fat intake and focusing on unsaturated fats present in nuts, seeds, and olive oil.
#
# ### Hormonal and Gender-Specific Factors
#
# **Gestational Diabetes:** Women with a history of gestational diabetes manifest a higher risk of developing T2D later in life. Early postpartum screening (at 6 to 12 weeks) is critical to identify and manage glucose abnormalities. Evidence supports that lifestyle interventions postpartum, particularly those that harness both dietary and exercise modifications, can effectively reduce the progression to T2D.
#
# **Polycystic Ovary Syndrome (PCOS):** PCOS, characterized by hyperandrogenism and insulin resistance, confers a 5- to 10-fold increased risk of T2D. Preventive strategies for women with PCOS include weight management, targeted physical activity, and dietary interventions designed to stabilize insulin levels.
#
# **Menopause:** The menopausal transition, with its associated decline in estrogen, leads to increased abdominal fat and insulin resistance. Women experiencing early menopause are at a higher risk for T2D. Hormone replacement therapy (HRT) has been explored as an adjunctive therapy to mitigate metabolic risks, though its use must be individualized and carefully weighed against potential risks. Lifestyle modifications during menopause, particularly increased physical activity and dietary adjustments, are strongly recommended.
#
# ### Ethnicity and Socioeconomic Considerations
#
# Ethnic disparities in T2D prevalence have been well documented. Research indicates that African American, Hispanic/Latina, American Indian/Alaska Native, and Asian/Pacific Islander women have elevated rates of developing T2D. The interplay between cultural dietary patterns, socioeconomic status, and access to healthcare services contributes to this disparity. Community-based interventions have been implemented in diverse populations, emphasizing culturally sensitive education, screening programs, and community support groups. Studies suggest that tailored strategies addressing these disparities can improve adherence to preventive measures and enhance health outcomes.
#
# ### Screening and Early Detection
#
# Regular screening plays a pivotal role in the early detection of prediabetes and T2D. The U.S. Preventive Services Task Force recommends screening for T2D in adults aged 35 to 70 years who are overweight or obese. Early detection through screening leads to timely lifestyle interventions that have been shown to delay or even prevent the onset of diabetes. Special attention is given to postpartum screening for women who experienced gestational diabetes.
#
# ## Discussion
#
# The multifaceted approach to diabetes prevention among women involves a combination of lifestyle changes and strategic public health interventions. The evidence presented in this report confirms that regular physical activity, weight management, and a balanced diet are central tenets in reducing T2D risk. However, hormonal influences unique to women, such as those seen with PCOS, gestational diabetes, and menopause, necessitate additional considerations and often tailored intervention strategies.
#
# One critical aspect of implementing these prevention strategies is ensuring that interventions are culturally sensitive and accessible. Socioeconomic factors can pose significant barriers to achieving lifestyle modifications. Thus, community-based programs, such as the Women Against Diabetes through Empowerment (WADE) program and initiatives by DiabetesSisters, play an important role in bridging the gap between healthcare recommendations and real-world practice.
#
# Additionally, the role of healthcare providers is pivotal in early screening and intervention. Regular risk assessments, patient education, and prompt follow-up can significantly alter the long-term trajectory of diabetes risk among women. Despite the proven benefits of lifestyle interventions, adherence remains a challenge. In this context, behavioral counseling and support systems become invaluable.
#
# Recent systematic reviews and meta-analyses have identified both the strengths and limitations of current preventive strategies. Although lifestyle interventions consistently show a reduction in diabetes incidence, methodological limitations and inequalities in study designs make it difficult to generalize findings across all female populations. Therefore, further high-quality randomized controlled trials (RCTs) are necessary to refine these interventions and understand the long-term impact of preventive strategies on different subgroups of women.
#
# ## Conclusion
#
# Preventing type 2 diabetes in females requires a comprehensive, tailored approach that combines regular physical activity, weight management, and a balanced diet with targeted interventions addressing unique physiological and hormonal challenges. Early detection through regular screening is crucial, especially for high-risk groups such as women with a history of gestational diabetes or PCOS, and for those undergoing menopausal transitions.
#
# Public health initiatives and community support programs can further enhance adherence to preventive measures and reduce disparities among diverse populations. While current evidence supports the effectiveness of lifestyle interventions, additional research is warranted to optimize these strategies across all subpopulations of women. The integration of clinical guidelines with evidence-based practices provides healthcare professionals with the necessary tools to implement effective diabetes prevention programs, ultimately improving patient outcomes and reducing the global burden of T2D.
#
# ## References
#
# 1. American Diabetes Association. (n.d.). Exercise and Diabetes. Retrieved from [diabetesjournals.org](https://diabetesjournals.org/care/article/39/11/2065/37249/physical-activity-exercise-and-diabetes)
# 2. Mayo Clinic. (n.d.). Diabetes prevention. Retrieved from [mayoclinic.org](https://www.mayoclinic.org/diseases-conditions/type-2-diabetes/in-depth/diabetes-prevention/art-20047639)
# 3. National Institute of Diabetes and Digestive and Kidney Diseases. (n.d.). Preventing Type 2 Diabetes. Retrieved from [niddk.nih.gov](https://www.niddk.nih.gov/health-information/diabetes/overview/preventing-type-2-diabetes/)
# 4. U.S. Preventive Services Task Force. (n.d.). Screening for Prediabetes and Type 2 Diabetes. Retrieved from [uspreventiveservicestaskforce.org](https://www.uspreventiveservicestaskforce.org/uspstf/document/RecommendationStatementFinal/screening-for-prediabetes-and-type-2-diabetes)
# 5. PubMed Central. (n.d.). Studies on Gestational Diabetes and Prevention Strategies. Retrieved from [pubmed.ncbi.nlm.nih.gov](https://pubmed.ncbi.nlm.nih.gov/32762924/)
#
# *Note: The references included are excerpts from a broader literature base and serve to illustrate the integration of high-quality clinical evidence and guidelines in diabetes prevention in women.*
#
#
#
# =====FOLLOW UP QUESTIONS=====
#
#
# 1. How do specific exercise modalities (aerobic vs. resistance training) differentially impact insulin sensitivity in women of various age groups?
# 2. What are the long-term effects of tailored dietary interventions in women with a history of gestational diabetes on subsequent T2D incidence?
# 3. How can emerging digital health interventions enhance adherence to lifestyle modifications in diverse and underserved female populations?
# 4. What role do hormonal therapies, including HRT, play in mitigating metabolic syndrome risks during the menopausal transition in women?
# 5. How effective are culturally tailored community-based programs in reducing ethnic disparities in diabetes prevention outcomes among women?

# %% [markdown]
# ---
#
# ## Sample Report in Markdown
#
# ---

# %% [markdown]
# # OpenAI Agents SDK: A Comprehensive Report
#
# *Published: October 2023*
#
# ## Table of Contents
#
# 1. [Introduction](#introduction)
# 2. [Core Concepts and Key Features](#core-concepts-and-key-features)
# 3. [Architecture and Developer Experience](#architecture-and-developer-experience)
# 4. [Comparative Analysis with Alternative Frameworks](#comparative-analysis-with-alternative-frameworks)
# 5. [Integrations and Real-World Applications](#integrations-and-real-world-applications)
# 6. [Troubleshooting, Observability, and Debugging](#troubleshooting-observability-and-debugging)
# 7. [Community Impact and Future Directions](#community-impact-and-future-directions)
# 8. [Conclusion](#conclusion)
#
# ---
#
# ## Introduction
#
# In March 2025, OpenAI released the Agents SDK, a groundbreaking, open-source framework aimed at simplifying the development of autonomous AI agents capable of performing intricate tasks with minimal human intervention. Designed with a Python-first approach, the SDK offers a minimal set of abstractions, yet provides all the necessary components to build, debug, and optimize multi-agent workflows. The release marked a significant milestone for developers who seek to integrate large language models (LLMs) with advanced task delegation mechanisms, enabling next-generation automation in various industries.
#
# The primary goal of the OpenAI Agents SDK is to streamline the creation of agentic applications by offering core primitives such as *agents*, *handoffs*, and *guardrails*. These primitives are essential for orchestrating autonomous AI systems that perform key functions such as web search, file operations, and even actions on a computer. This report delves into the SDK's features, its operational architecture, integration capabilities, and how it compares to other frameworks in the rapidly evolving landscape of AI development tools.
#
# ## Core Concepts and Key Features
#
# ### Agents
#
# At the heart of the SDK are **agents**—intelligent entities that encapsulate a specific set of instructions and tools. Each agent is built on top of a large language model and can be customized with its own personality, domain expertise, and operational directives. For example, a "Math Tutor" agent could be designed to solve math problems by explaining each step clearly.
#
# **Key elements of an agent include:**
#
# - **Instructions:** Specific guidelines that shape the agent's responses and behavior in the context of its designated role.
# - **Tools:** Predefined or dynamically integrated tools that the agent can leverage to access external resources (e.g., web search or file search functionalities).
#
# ### Handoffs
#
# A unique feature introduced by the SDK is the concept of **handoffs**. Handoffs allow agents to delegate tasks to one another based on expertise and contextual needs. This orchestration paves the way for sophisticated workflows where multiple agents work in tandem, each contributing its specialized capabilities to complete a complex task.
#
# ### Guardrails
#
# Safety and reliability remain a cornerstone in AI development, and the SDK introduces **guardrails** as a means of controlling input and output validation. Guardrails help ensure that agents operate within defined safety parameters, preventing unintended actions and mitigating risks associated with autonomous decision-making.
#
# ### Built-in Debugging and Observability
#
# The development process is further enhanced by built-in **tracing and visualization tools**. These tools offer real-time insights into agent interactions, tool invocations, and decision-making pathways, thereby making debugging and optimization more accessible and systematic. The tracing functionality is a vital feature for developers looking to fine-tune agent performance in production environments.
#
# ## Architecture and Developer Experience
#
# ### Python-First Approach
#
# The SDK is inherently Python-based, making it highly accessible to the vast community of Python developers. By leveraging existing language features without introducing excessive abstractions, the SDK provides both simplicity and power. The installation is straightforward:
#
# ```bash
# mkdir my_project
# cd my_project
# python -m venv .venv
# source .venv/bin/activate
# pip install openai-agents
# ```
#
# Once installed, developers can create and configure agents with minimal boilerplate code. The emphasis on a minimal learning curve has been a significant point of praise among early adopters.
#
# ### Developer Tools and Tutorials
#
# In addition to comprehensive official documentation available on OpenAI’s GitHub pages, the community has contributed numerous tutorials and code examples. Video tutorials by experts such as Sam Witteveen and James Briggs provide hands-on demonstrations, ranging from simple agent creation to more sophisticated scenarios involving parallel execution and advanced tool integrations.
#
# ### Use of Python's Ecosystem
#
# The integration with Python’s ecosystem means that developers can immediately apply a range of established libraries and frameworks. For instance, utilizing Pydantic for input validation in guardrails or leveraging visualization libraries to display agent workflows are examples of how the SDK embraces the strengths of Python.
#
# ## Comparative Analysis with Alternative Frameworks
#
# While the OpenAI Agents SDK has received acclaim for its simplicity and robust integration with OpenAI’s ecosystem, other frameworks such as LangGraph, CrewAI, and AutoGen have emerged as viable alternatives. Here’s how they compare:
#
# - **LangGraph:** Known for its graph-based architecture, LangGraph is ideal for handling complex and cyclical workflows that require sophisticated state management. However, it comes with a steeper learning curve, making it less accessible for projects that require quick prototyping.
#
# - **CrewAI:** Emphasizing a role-based multi-agent system, CrewAI excels in scenarios where collaboration among agents is critical. Its design promotes clear segregation of duties among different agents, which can be beneficial in customer service or large-scale business automation.
#
# - **AutoGen:** This framework supports flexible conversation patterns and diverse agent interactions, particularly useful in applications where adaptive dialogue is essential. Nevertheless, AutoGen may introduce additional overhead when managing state and coordinating multiple agents.
#
# In contrast, the OpenAI Agents SDK strikes an effective balance by offering a lightweight yet powerful toolset geared towards production readiness. Its strengths lie in its minimal abstractions, ease of integration with various tools (like web search and file search), and built-in observability features that are crucial for debugging and tracing agent interactions.
#
# ## Integrations and Real-World Applications
#
# ### Diverse Integrations
#
# The real power of the OpenAI Agents SDK surfaces when it is integrated with other systems and platforms. Notable integrations include:
#
# - **Box Integration:** Enhancing enterprise content management, Box has adopted the SDK to enable secure AI-powered data processing. This integration allows agents to reliably access and interpret proprietary data.
#
# - **Coinbase AgentKit:** With financial capabilities in mind, Coinbase introduced AgentKit, leveraging the SDK to incorporate financial operations and risk analysis directly into AI agents.
#
# - **Milvus and Ollama:** These integrations allow the SDK to handle high-performance data queries and run agents on local infrastructure respectively, ensuring both speed and privacy.
#
# ### Real-World Applications
#
# The versatility of the SDK lends itself to a multitude of applications:
#
# - **Customer Support:** Automated agents can be built to handle customer inquiries, providing faster and more accurate responses while reducing workload on human agents.
#
# - **Content Generation:** In marketing and media, agents can generate high-quality articles, detailed reports, and even code reviews with built-in content guidelines.
#
# - **Financial Analysis:** Specialized agents capable of real-time data fetching and market analysis can generate actionable insights for investors and analysts.
#
# - **Health and Wellness:** Custom agents can handle tasks such as appointment scheduling, patient record management, and even provide personalized fitness and dietary recommendations.
#
# - **Educational Tools:** Intelligent tutoring agents can assist students by providing personalized learning experiences and instant feedback on assignments.
#
# These applications underscore the SDK’s transformative potential across various industries, driving the trend towards increased automation and efficiency.
#
# ## Troubleshooting, Observability, and Debugging
#
# ### Common Issues and Solutions
#
# As with any cutting-edge technology, developers working with the OpenAI Agents SDK have encountered challenges:
#
# - **API Key Management:** Authentication errors due to missing or invalid API keys are common. The solution involves ensuring that the `OPENAI_API_KEY` environment variable is correctly set or programmatically configured using OpenAI’s helper functions.
#
# - **Rate Limitations:** Rate limits, an intrinsic challenge with API-based services, require developers to monitor dashboard usage and implement retry strategies with exponential backoff.
#
# - **Response Delays:** Network latency and high server loads can result in unexpected delays. Developers are advised to check network settings, adhere to best practices in setting request timeouts, and monitor OpenAI’s service status.
#
# ### Built-In Tracing Capabilities
#
# The SDK provides robust tracing tools that log agent inputs, outputs, tool interactions, and error messages. This level of observability is crucial for debugging complex workflows and allows developers to visualize the agent’s decision-making process in real time. By configuring a `TracingConfig` object, developers can capture detailed insights and identify performance bottlenecks.
#
# ### Best Practices
#
# - **Prompt Engineering:** Refine prompts to reduce ambiguity and minimize unexpected outputs.
# - **Layered Validation:** Use guardrails extensively to ensure inputs and outputs are verified at multiple layers.
# - **Modular Design:** Break complex tasks into smaller, more manageable components using handoffs to delegate tasks appropriately.
#
# ## Community Impact and Future Directions
#
# ### Developer and Enterprise Adoption
#
# The release of the OpenAI Agents SDK has been met with enthusiasm within the developer community. Its ease of use, combined with comprehensive documentation and community-driven resources (such as tutorials on Class Central and DataCamp), has accelerated its adoption across educational, enterprise, and research sectors.
#
# Several leading organizations, including Box and Coinbase, have integrated the SDK into their workflows, demonstrating its capability to drive real-world business solutions. The open-source nature of the SDK, licensed under the MIT License, further encourages widespread industrial collaboration and innovation.
#
# ### Future Prospects
#
# Looking forward, OpenAI plans to extend the SDK’s support beyond Python, potentially embracing other programming languages like JavaScript. Additionally, future updates are anticipated to expand tool integrations, further enhance safety mechanisms, and streamline the development of multi-agent ecosystems. Planned deprecations of older APIs, such as the Assistants API in favor of the more unified Responses API, underline the SDK’s evolving roadmap aimed at future-proofing agentic applications.
#
# ## Conclusion
#
# The OpenAI Agents SDK represents a significant step forward in the field of AI development. Its lightweight, Python-first framework facilitates the creation of autonomous agents that can handle a wide array of tasks—from simple inquiries to complex multi-agent systems. The SDK’s robust integration capabilities, combined with its focus on safety and observability, make it an ideal choice for both developers and enterprises seeking to build reliable, scalable agentic applications.
#
# In summary, the SDK not only lowers the barrier to entry for developing sophisticated AI applications but also sets the stage for further innovations as the ecosystem evolves. It is poised to become a standard toolkit for the next generation of AI-driven technologies, empowering users across sectors to achieve greater efficiency and creativity in task automation.
#
# ---
#
# *For further reading, developers are encouraged to visit the official OpenAI documentation, join the community forums, and explore real-world use cases to deepen their understanding of this transformative tool.*
